# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from sklearn.metrics import confusion_matrix, accuracy_score
import os
import random
import cv2
import shutil
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
import seaborn as sns

# %%
base_dir = 'D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8'
output_dir = 'D:/PROJECT/Dataset/BoneFractureYolo8'

class_directories = ['elbow_positive', 'fingers_positive', 'forearm_fracture', 'humerus_fracture',
                     'humerus', 'shoulder_fracture', 'wrist_positive']
splits = ['train', 'valid', 'test']

# %%
for split in splits:
    for class_dir in class_directories:
        os.makedirs(os.path.join(output_dir, split, class_dir), exist_ok=True)

# %%
def extract_class_labels(label_content):
    class_ids = set()
    lines = label_content.strip().split('\n')

    for line in lines:
        if line.strip():
            parts = line.split()
            if len(parts) > 0:
                try:
                    class_id = int(parts[0])
                    class_ids.add(class_id)
                except ValueError:
                    print(f"Skipping invalid line: {line}")
    return class_ids

# %%
def extract_class_labels_from_file(file_path):
    with open(file_path, 'r') as file:
        label_content = file.read()
    return extract_class_labels(label_content)

# %%
def move_image_to_class_folder(image_path, class_ids, split):
    for class_id in class_ids:
        class_folder = class_directories[class_id]
        output_path = os.path.join(output_dir, split, class_folder)
        if os.path.exists(image_path):
            shutil.copy(image_path, output_path)
            print(f"Moved {image_path} to {output_path}")
        else:
            print(f"Image file {image_path} not found")

# %%
for split in splits:
    labels_dir = os.path.join(base_dir, split, 'labels')
    images_dir = os.path.join(base_dir, split, 'images')

    for label_file in os.listdir(labels_dir):
        if label_file.endswith('.txt'):
            label_file_path = os.path.join(labels_dir, label_file)
            image_file = label_file.replace('.txt', '.jpg')

            image_path = os.path.join(images_dir, image_file)

            class_ids = extract_class_labels_from_file(label_file_path)

            if class_ids:
                move_image_to_class_folder(image_path, class_ids, split)
# Out:
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\distal-humeral-fractures-2-_JPEG.rf.39ba3f53047ecb4064613850a1c76fc1.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\distal-humeral-fractures-2-_JPEG.rf.525ce876785d0fd798ec3af1593e5bc1.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\distal-humeral-fractures-2-_JPEG.rf.f9442db05ec473187c60870d407c9e8f.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\elbow-dislocation-with-coronoid-process-fracture_jpg.rf.234153519323ba2b9aa2e603b0a43771.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\elbow-dislocation-with-coronoid-process-fracture_jpg.rf.75b67d2e40fe637ba2838e1283f970c5.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\elbow-dislocation-with-coronoid-process-fracture_jpg.rf.76486fb6ffe2b6c7da0e4922e58a088f.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\fracture-of-the-humeral-capitellum-milch-type-1-1-1-_jpg.rf.4c16d0817782b56497b9f18bca2b0fdd.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\fracture-of-the-humeral-capitellum-milch-type-1-1-1-_jpg.rf.8b022b79c884d0b37d923a3c961591c6.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\fracture-of-the-humeral-capitellum-milch-type-1-1-1-_jpg.rf.f40a3ca2a57d511a40839bd1ca615d54.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\elbow_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_0_png.rf.bc222874fa14e205b638e87ddad52b9d.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\shoulder_fracture
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_0_png.rf.c864ea1d0d7a6ba347b3bd6fa51bf4c9.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\shoulder_fracture
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_0_png.rf.d44c62635f246b717a95453d650ac2cb.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\shoulder_fracture
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_1002_png.rf.1feafce607366113c97124dc22d52328.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\wrist_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_1002_png.rf.67c46c90c7089ef2ffa40b5fa22e4ad1.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\wrist_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_1002_png.rf.c94d11a79032d6beb4ce4d876c9f7fda.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\wrist_positive
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_1010_png.rf.47d67fce58c4e28fb83b9ed08ad0e8fd.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\humerus
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_1010_png.rf.65f54641e628d0952fc45df00ef5e7ff.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\humerus
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_1010_png.rf.f89583d2a87e12690f29a1044e4defed.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\train\humerus
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\train\images\image1_
jpg to D:/PROJECT/Dataset/BoneFractureYolo8\test\forearm_fracture
# Moved D:/PROJECT/Dataset/bone fracture detection.v4-v4.yolov8\test\images\image2_953_png.rf.97a41890b4badde45bfc390f9f5c9d12.jpg to D:/PROJECT/Dataset/BoneFractureYolo8\test\forearm_fracture

# %%
def display_random_images(split='train'):
    fig, axes = plt.subplots(1, len(class_directories), figsize=(20, 5))
    fig.suptitle(f'Random Images from {split} Set')

    for i, class_dir in enumerate(class_directories):
        class_path = os.path.join(output_dir, split, class_dir)
        image_files = [f for f in os.listdir(class_path) if f.endswith(('.jpg', '.png'))]

        if len(image_files) > 0:
            random_image = random.choice(image_files)
            image_path = os.path.join(class_path, random_image)
            img = Image.open(image_path)
            axes[i].imshow(img)
            axes[i].axis('off')
            axes[i].set_title(class_dir)
        else:
           print(f"No images found in class directory: {class_dir}")

    plt.show()

display_random_images(split='train')

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'valid': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
}

# %%
dir_path = 'D:/PROJECT/Dataset/BoneFractureYolo8/test/humerus_fracture'

if os.path.exists(dir_path) and not os.listdir(dir_path):
    os.rmdir(dir_path)
    print(f"Directory {dir_path} deleted.")
else:
    print(f"Directory {dir_path} is not empty or does not exist.")
# Out:
# Directory D:/PROJECT/Dataset/BoneFractureYolo8/test/humerus_fracture deleted.

# %%
dir_path = 'D:/PROJECT/Dataset/BoneFractureYolo8/valid/humerus_fracture'

if os.path.exists(dir_path) and not os.listdir(dir_path):
    os.rmdir(dir_path)
    print(f"Directory {dir_path} deleted.")
else:
    print(f"Directory {dir_path} is not empty or does not exist.")
# Out:
# Directory D:/PROJECT/Dataset/BoneFractureYolo8/valid/humerus_fracture deleted.

# %% [markdown]
# ##Load the Dataset

# %%
train_dataset = datasets.ImageFolder('D:/PROJECT/Dataset/train', transform=data_transforms['train'])
valid_dataset = datasets.ImageFolder('D:/PROJECT/Dataset/valid', transform=data_transforms['valid'])
test_dataset = datasets.ImageFolder('D:/PROJECT/Dataset/test', transform=data_transforms['test'])

# %%
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
num_classes = len(train_dataset.classes)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = models.resnet18(pretrained=True)
# Out:
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\sarth/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100.0%

# %%
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, scheduler, num_epochs=10):
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')

        # Training phase
        model.train()
        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)

            # Backward pass and optimization
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        scheduler.step()

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = running_corrects.double() / len(train_loader.dataset)

        print(f'Train Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

        # Validation phase
        model.eval()
        val_running_corrects = 0

        with torch.no_grad():
            for inputs, labels in valid_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                val_running_corrects += torch.sum(preds == labels.data)
        val_acc = val_running_corrects.double() / len(valid_loader.dataset)
        print(f'Validation Acc: {val_acc:.4f}')

        # Save the best model
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), 'best_model.pth')

    print(f'Best Validation Accuracy: {best_acc:.4f}')

# %%
train_model(model, train_loader, valid_loader, criterion, optimizer, scheduler, num_epochs=12)
# Out:
# Epoch 1/12
# Train Loss: 1.1297 Acc: 0.6026
# Validation Acc: 0.5318
# Epoch 2/12
# Train Loss: 0.5981 Acc: 0.7724
# Validation Acc: 0.4971
# Epoch 3/12
# Train Loss: 0.4728 Acc: 0.8222
# Validation Acc: 0.5896
# Epoch 4/12
# Train Loss: 0.4471 Acc: 0.8323
# Validation Acc: 0.5491
# Epoch 5/12
# Train Loss: 0.4211 Acc: 0.8486
# Validation Acc: 0.6705
# Epoch 6/12
# Train Loss: 0.2363 Acc: 0.9177
# Validation Acc: 0.6705
# Epoch 7/12
# Train Loss: 0.2425 Acc: 0.9136
# Validation Acc: 0.6127
# Epoch 8/12
# Train Loss: 0.1511 Acc: 0.9482
# Validation Acc: 0.6936
# Epoch 9/12
# Train Loss: 0.0961 Acc: 0.9726
# Validation Acc: 0.6994
# Epoch 10/12
# Train Loss: 0.0608 Acc: 0.9797
# Validation Acc: 0.7052
# Epoch 11/12
# Train Loss: 0.0509 Acc: 0.9898
# Validation Acc: 0.7110
# Epoch 12/12
# Train Loss: 0.0438 Acc: 0.9909
# Validation Acc: 0.6879
# Best Validation Accuracy: 0.7110

# %%
import torch
torch.save(model, "D:/PROJECT/Result/resnet_model.pth")

# %%
def evaluate_model(model, test_loader):
    model.load_state_dict(torch.load('best_model.pth'))
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return all_labels, all_preds

# Get predictions
all_labels, all_preds = evaluate_model(model, test_loader)
cm = confusion_matrix(all_labels, all_preds)
acc = accuracy_score(all_labels, all_preds)
print(f'Test Accuracy: {acc:.4f}')

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# C:\Users\sarth\AppData\Local\Temp\ipykernel_11244\3893437378.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# Test Accuracy: 0.6145

# %%
import torch
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def evaluate_model(model, test_loader, device):
    """
    Evaluate the performance of a model on a test dataset.

    Args:
        model: The PyTorch model to be evaluated.
        test_loader: DataLoader for the test dataset.
        device: Device ('cpu' or 'cuda') to run the evaluation on.

    Returns:
        all_labels: True labels from the test dataset.
        all_preds: Predicted labels from the model.
    """
    try:
        # Load model weights
        model.load_state_dict(torch.load('best_model.pth'))
        model.eval()
        model.to(device)

        all_preds = []
        all_labels = []

        # Disable gradient calculations for evaluation
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)  # Get predictions
                all_preds.extend(preds.cpu().numpy())  # Move to CPU
                all_labels.extend(labels.cpu().numpy())  # Move to CPU

        return all_labels, all_preds

    except Exception as e:
        print(f"Error during evaluation: {e}")
        return [], []

def plot_confusion_matrix(cm, class_names, title="Confusion Matrix"):
    """
    Plot a confusion matrix using Seaborn.

    Args:
        cm: Confusion matrix (2D array).
        class_names: List of class names.
        title: Title for the plot.
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title(title)
    plt.show()

# Evaluate the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Automatically choose the device
all_labels, all_preds = evaluate_model(model, test_loader, device)

if all_labels and all_preds:
    # Compute metrics
    cm = confusion_matrix(all_labels, all_preds)
    acc = accuracy_score(all_labels, all_preds)
    report = classification_report(all_labels, all_preds, target_names=train_dataset.classes)

    # Print metrics
    print(f"Test Accuracy: {acc:.4f}")
    print("\nClassification Report:\n", report)

    # Plot the confusion matrix
    plot_confusion_matrix(cm, train_dataset.classes)
else:
    print("Evaluation failed due to errors.")
# Out:
# C:\Users\sarth\AppData\Local\Temp\ipykernel_11244\1369067028.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\sarth\miniconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Accuracy: 0.6145
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#    elbow_positive       0.93      1.00      0.96        13
#  fingers_positive       0.88      0.68      0.77        22
#  forearm_fracture       1.00      0.69      0.82        13
#           humerus       0.93      1.00      0.97        14
#  humerus_fracture       0.00      0.00      0.00        15
# shoulder_fracture       0.00      0.00      0.00         6
#    wrist_positive       0.00      0.00      0.00         0
#
#          accuracy                           0.61        83
#         macro avg       0.53      0.48      0.50        83
#      weighted avg       0.69      0.61      0.65        83
